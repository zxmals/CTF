# %% [markdown]
# #### 摩斯电码-解密

# %%
mos_dict = {
"．━":"A"
,"．":"E"
,"．．":"I"
,"━━":"M"
,"━━．━":"Q"
,"．．━":"U"
,"━．．．":"B"
,"．．━．":"F"
,"．━━━":"J"
,"━．":"N"
,"．━．":"R"
,"．．．━":"V"
,"━．━．":"C"
,"━━．":"G"
,"━．━":"K"
,"━━━":"O"
,"．．．":"S"
,"．━━":"W"
,"━．．":"D"
,"．．．．":"H"
,"．━．．":"L"
,"．━━．":"P"
,"━":"T"
,"━．．━":"X"
,"━．━━":"Y"
,"━━．．":"Z"
,"━━━━━":"0"
,"．．．．━":"4"
,"━━━．．":"8"
,"．━━━━":"1"
,"．．．．．":"5"
,"━━━━．":"9"
,"．．━━━":"2"
,"━．．．．":"6"
,"．．．━━":"3"
,"━━．．．":"7"
,"．━．━．━":"."
,"．．━━．．":"?"
,"━．━．━━":"!"
,"━．━━．":"("
,"．━━．━．":"@"
,"━━━．．．":":"
,"━．．．━":"="
,"━．．．．━":"━"
,"━．━━．━":")"
,"━━．．━━":","
,"．━━━━．":"'"
,"．．━━．━":"_"
,"．．．━．．━":"$"
,"━．━．━．":";"
,"━．．━．":"/"
,"．━．．━．":'"'
,"．．．．":"&"
,"．━━．━":"à或?"
,"．．━━．":"e"
,"━．━━．":"?"
,"．．．━．":"?"
,"．━．━":"?或?"
,"．．━．．":"é"
,"．━━━．":"?"
,"．━━．．":"t"
,"━━━━":"ch"
,"．━．．━":"è"
,"━━．━━":"?"
,"．．━━":"ü或?"
,"━．━．．":"?或?"
,"━━．━．":"?"
,"━━━．":"?或?"
,"．━．━．":"AR"
,"━．．．━":"BT"
,"．━．．．":"AS"
,"━．━":"K"
,"．．．━．━":"SK"}

# %%
mos_str = "..... -... -.-. ----. ..--- ..... -.... ....- ----. -.-. -... ----- .---- ---.. ---.. ..-. ..... ..--- . -.... .---- --... -.. --... ----- ----. ..--- ----. .---- ----. .---- -.-."
mos_str = mos_str.replace('.',"．")
mos_str = mos_str.replace('-',"━")
res_li = [mos_dict[k] for k in mos_str.split()]
res_str = ""
for re_c in res_li:
    res_str += re_c
print(res_str)
print(res_str.lower())
# Out:
# CTFWPEI08732?23DZ
# ctfwpei08732?23dz
